# %%
import numpy as np

a =np.random.randn(2)
b =np.random.randn(2)

anorm =np.linalg.norm(a)
bnorm =np.linalg.norm(b)

print(f"a ={a}")
print(f"b ={b}")
print(f"anorm ={anorm}")
print(f"bnorm ={bnorm}")

theta =np.arccos( np.dot(a,b) / ( anorm * bnorm ) )

print( f"theta =np.arccos( np.dot(a,b) / ( anorm * bnorm ) ) ={theta} radians" )
theta_deg =theta * (180 / np.pi);
print( f"theta_deg = theta * (180 / np.pi) = {theta_deg}" ) ;

print( "defn dot product :   dot(a,b) = |a| |b| cos(theta)" )
print( "defn dot product :   cos(theta) = dot(a,b) / (|a| |b|)" )
print( "defn dot product :   theta = arccos( dot(a,b) / (|a| |b|) )" )

u =np.array([0,1])
v =np.array([1,1])
theta_deg =(180/np.pi) * np.arccos( np.dot(u,v) / ( np.linalg.norm( u)*np.linalg.norm( v) ))
print( f"\n u ={u}\n v ={v} theta_deg =
# Out:
# a =[0.61266334 0.95944593]
# b =[-0.81107868  1.80114643]
# anorm =1.1383729018817652
# bnorm =1.9753422693118383
# theta =np.arccos( np.dot(a,b) / ( anorm * bnorm ) ) =0.991404356983709 radians
# theta_deg = theta * (180 / np.pi) = 56.803285446047745
